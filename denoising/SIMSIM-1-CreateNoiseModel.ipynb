# %% [markdown]
# # Generate a Histogram Based Noise Model
# We will use pairs of noisy observations $x_i$ and clean signal $s_i$ (created by averaging many noisy images) to estimate the conditional distribution $p(x_i|s_i)$.
# Note that this noise model is independent of the image content. It is a property of the camera and imaging conditions.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle

import pn2v.utils
import pn2v.histNoiseModel
from tifffile import imread
import glob

# %% [markdown]
# ### The data
# The noise model is a characteristic of your camera.
# To measure your noise model you have record a series of images, using the same camera and imaging settings (gain, em-gain, read-out-parameters,...) as in your experiments.
# However, the content of these images does not matter, as long as they cover the required range of intensities.
# We recommend to simply record 500 images of your slightly closed and defocussed field diaphragm (see images below).
# It is important that your exposure, lighting and all imaging settings are constant for the entire sequence and that **NOTHING IN THE IMAGE IS MOVING**.
# When recording a image sequence like this, make sure to cover desired range of intensities but **DO NOT  SATURATE** your detector.

# %%
path="/home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/"
files=iles=glob.glob(path+'*.tif')

data=[]
for f in files:
    data.append(imread(f).astype(np.float32))
    print('loading',f)

data =np.array(data)
print(data.shape)

#if len(data.shape)==4:
#    data.shape=(data.shape[0]*data.shape[1],data.shape[2],data.shape[3])

print(data.shape)
# Out:
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0044.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0077.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0095.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0105.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0136.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0078.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0110.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0139.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0051.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0080.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0123.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0062.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0109.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0061.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0048.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0083.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0120.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0052.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0099.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0113.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0106.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0047.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0096.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0135.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0074.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0133.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0090.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0072.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0100.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0068.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0041.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0129.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0054.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0115.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0067.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0126.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0085.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0125.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0086.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0064.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0116.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0057.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0089.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0042.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0103.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0071.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0119.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0130.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0093.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0058.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0166.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0027.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0184.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0155.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0014.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0001.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0169.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0140.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0028.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0032.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0191.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0173.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0170.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0018.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0031.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0159.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0192.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0143.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0188.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0002.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0017.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0156.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0024.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0187.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0165.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0181.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0022.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0163.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0179.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0011.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0038.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0150.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0145.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0004.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0176.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0194.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0037.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0197.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0034.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0175.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0007.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0146.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0198.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0153.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0012.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0008.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0160.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0182.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0149.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0021.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0006.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0147.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0035.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0196.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0174.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0161.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0009.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0020.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0183.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0148.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0199.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0152.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0013.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0010.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0178.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0151.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0039.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0023.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0180.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0162.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0177.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0036.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0195.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0144.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0005.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0142.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0189.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0003.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0019.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0171.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0158.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0193.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0030.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0186.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0025.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0164.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0016.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0157.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0154.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0015.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0167.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0185.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0026.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0190.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0033.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0172.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0168.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0000.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0029.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0141.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0117.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0056.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0087.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0124.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0065.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0118.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0070.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0092.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0059.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0131.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0088.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0043.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0102.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0069.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0101.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0128.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0040.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0091.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0132.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0073.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0066.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0084.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0127.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0055.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0114.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0053.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0098.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0112.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0060.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0108.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0121.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0049.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0082.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0134.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0097.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0075.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0107.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0046.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0045.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0104.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0076.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0137.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0094.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0122.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0081.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0063.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0111.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0079.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0050.tif
# loading /home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/SimSimNoiseModelSig1000/camsim/matslines_ccd_sig1000_exp1_rn8_bgrd0_947_0138.tif
# (200, 225, 128, 128)
# (200, 225, 128, 128)

# %%
observation=data
print(observation.shape)
# Out:
# (200, 225, 128, 128)

# %%
# The data contains 100 images of a static sample.
# We estimate the clean signal by averaging all images.
signal=np.mean(observation[:,...],axis=0)[np.newaxis,...]

# Let's look the raw data and our pseudo ground truth signal
plt.figure(figsize=(12, 12))
plt.subplot(1, 2, 2)
plt.title(label='average (ground truth)')
plt.imshow(signal[0][40],cmap='gray')
plt.subplot(1, 2, 1)
plt.title(label='single raw image')
plt.imshow(observation[3][40],cmap='gray')
plt.show()

# %% [markdown]
# Let us first take a look at the distribution of signals $s_i$ that are present in this data.
# While most pixels are background, we comfortably cover a range to values of 30000 and below. The signals in the images we want to denoise should be within this range.

# %%
checkSignalHist = np.histogram(signal, bins=256)
plt.plot( checkSignalHist[1][:-1], np.clip(checkSignalHist[0],0,1e10))

# %% [markdown]
# ### Creating the noise model
# Using the raw pixels $x_i$, and our pseudo ground truth $s_i$, we are now creating a 2D histogram. Rows correspond to different signals $s_i$ and columns to different observations $x_i$. The histogram is normalized so that every row sums to one. It describes the distribution $p(x_i|s_i)$ for each $s_i$. This distribution is our noise model.

# %%
# We set the range of values we want to cover with our model.
# The pixel intensities in the images you want to denoise have to lie within this range.
# We expect our intensities to lie within [350,6500].
minVal, maxVal =86.5, 270.5
bins = int((270-86)/4)
print(bins)

# We are creating the histogram.
# This can take a minute.
histogramFD = pn2v.histNoiseModel.createHistogram(bins,minVal,maxVal,observation,signal)
# Out:
# 46

# %%
# Saving histogram to disc.
saveP='/home/krull/fileserver/N2V-SimSim/data/simsim_for_n2v/matslines3d/camsim/'
np.save(saveP+'noiseModelSig1000.npy', histogramFD)


histogramFD=histogramFD[0]

# %%
# Let's look at the noise model
plt.xlabel('observation bin')
plt.ylabel('signal bin')
plt.imshow(histogramFD**0.25, cmap='gray')
plt.show()
print(np.min(observation),np.max(observation))
# Out:
# 89.0 278.0

# %%
xvals=np.arange(bins)/float(bins)*(maxVal-minVal)+minVal
plt.xlabel('observation')
plt.ylabel('probability density')

# We will now look at the noise distributions for different signals s_i,
# by plotting individual rows of the histogram
index=10
s=((index+0.5)/float(bins)*(maxVal-minVal)+minVal)
plt.plot(xvals,histogramFD[index,:], label='bin='+str(index)+' signal='+str(np.round(s,2)))

index=12
s=((index+0.5)/float(bins)*(maxVal-minVal)+minVal)
plt.plot(xvals,histogramFD[index,:], label='bin='+str(index)+' signal='+str(np.round(s,2)))

index=13
s=((index+0.5)/float(bins)*(maxVal-minVal)+minVal)
plt.plot(xvals,histogramFD[index,:], label='bin='+str(index)+' signal='+str(np.round(s,2)))

plt.legend()
plt.show()
