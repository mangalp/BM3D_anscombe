# %%
import numpy as np
from matplotlib import pyplot as plt
from tifffile import imread, imsave

# %%
path='../../../data/fairSim-full/Zeiss/'
image=imread(path+'Zeiss_Mito_600nm_crop.tif').astype(np.float32)

# %%
def PSNR(gt, pred, range_=None ):
    if range_ is None:
        range_=np.max(gt)-np.min(gt)
    mse = np.mean((gt - pred)**2)
    return 20 * np.log10((range_)/np.sqrt(mse))
print (offset)
# Out:
# 122.0

# %%
#plt.imshow(image[3,0,500:700,500:700])
#plt.imshow(image)
a=5
offset=np.min(image)
imageNoise=[]
for i in range(5):
    a=2.0**((i-6))
    imageScaled=(image-offset)*a
    im=np.random.poisson(imageScaled)/a+offset
    imageNoise.append(im)
    print(i,a,PSNR(image,im))
    imsave(path+'/Zeiss_Mito_600nm_crop_Poisson-n'+str(i)+'.tif',im.astype(np.uint16),imagej=True)
# Out:
# 0 0.015625 28.888585309028805
# 1 0.03125 31.90232091222334
# 2 0.0625 34.9098116704661
# 3 0.125 37.92023626611219
# 4 0.25 40.93081671519088

# %%
#plt.imshow(imageNoise[3,0,500:700,500:700])
for im in imageNoise:
    print(im.shape)
    plt.imshow(im[3,0,50:150,50:150])
    plt.show()
    
plt.imshow(image[3,0,50:150,50:150])
plt.show()
# Out:
# (5, 25, 512, 512)
# (5, 25, 512, 512)
# (5, 25, 512, 512)
# (5, 25, 512, 512)
# (5, 25, 512, 512)
